# %% [markdown]
# # README
# ## Principe du package :
# Ce package sert à automatiser le passage d'une liste de surlignages/citations pris sous Neo Reader (boox) vers un modèle obsidian, avec saisie des tags et du type pour chaque citation, ainsi que des métadonnées.
# ## Opérations sur tablette :
# - surligner dans un texte (epub par exemple)
# - sommaire -> remarques
# - tout sélectionner -> partager
# - exportation vers d'autres comptes
# Puis aller chercher le fichier html dans google drive
# ## Opérations sur le programme:
# 1. mettre le fichier html dans le dossier
# 2. créer un fichier mardown dans le dossier
# 3. executer le code
# 4. suivre toutes les étapes JUSQU'AU BOUT (ne pas appuyer sur "terminer" avant d'être passé sur toutes les citations)
# 5. enregistrer dans le fichier markdown
# 6. copier coller le fichier markdown dans obsidian
# 7. vérifier le lien vers le livre dans obsidian

# %% [markdown]
# ___
# ## Notes pour développement :
# - afficher le bouton "terminé" uniquement à la fin
# - pouvoir fermer les fenêtres à tout moment sans conséquences pour annuler l'opération
# - (hard) récupérer les tags déjà présents sur obsidian pour de l'autocomplétion
# ## Fichier CSs lié aux callouts pour citations :
# ```css
# /* Callouts de type de document
#     /* Callout pour [!video] */
#     .callout[data-callout="video"] {
#         --callout-color: 255, 80, 80; /* rouge clair */
#         --callout-icon: "lucide-clapperboard";
#     }
#
#     /* Callout pour [!book] */
#     .callout[data-callout="book"] {
#         --callout-color: 80, 200, 120; /* vert pastel */
#         --callout-icon: "lucide-book";
#     }
#
#
# /* Callout de citation
#     /* Callout pour [!exemple] */
#     .callout[data-callout="exemple"] {
#         --callout-color: 204, 204, 0;
#         --callout-icon: "lucide-camera";
#     }
#
#     /* Callout pour [!revoir] */
#     .callout[data-callout="important"] {
#         --callout-color: 255, 153, 153; /* rouge */
#         --callout-icon: "lucide-triangle-alert";
#     }
#
#     /* Callout pour [!definition] */
#     .callout[data-callout="definition"] {
#         --callout-color: 51, 153, 255; /* bleu */
#         --callout-icon: "lucide-book-a";
#     }
#
#     /* Callout pour [!référence] */
#     .callout[data-callout="reference"] {
#         --callout-color: 0, 204, 102; /* vert */
#         --callout-icon: "lucide-bookmark";
#     }
#
#     /* Callout pour [!à revoir] */
#     .callout[data-callout="a-revoir"] {
#         --callout-color: 178, 102, 255; /* violet */
#         --callout-icon: "lucide-glasses";
#     }
# ```

# %% [markdown]
# ___
# # Structuration du html provenant de Neo Reader
#
# ## Titre :
# ```html
# <title>Nous ne sommes pas seuls_ Politique des soulevements terrestres - Lena Balaud & Antoine Chopot(author Antoine Chopot)</title>
# ```
#
# ## Exemple de citation dans le corps :
# ```html
# <div style="font-size: 14pt; text-align: left; margin-top: 0.5em; margin-bottom: 0.3em;"><span style="font-weight: bold; color: #48b4c1;">Introduction</span></div><div style="padding-top: 1em; padding-bottom: 1em; border-top: 1px dotted lightgray;"><div style="font-size: 10pt; margin-bottom: 1em; padding-left: 8px; border-left: 5px solid #ed6c00; color: #888888;">2025-07-06 23:45:32</div><div style="font-size: 12pt;"><span>l’Holocène</span></div></div><div style="font-size: 14pt; text-align: left; margin-top: 0.5em; margin-bottom: 0.3em;"><span style="font-weight: bold; color: #48b4c1;">Commune vitalité</span></div><div style="padding-top: 1em; padding-bottom: 1em; border-top: 1px dotted lightgray;"><div style="font-size: 10pt; margin-bottom: 1em; padding-left: 8px; border-left: 5px solid #ed6c00; color: #888888;">2025-07-06 23:48:13</div><div style="font-size: 12pt;"><span>Nous sommes entouré·es, traversé·es par d’autres « peuples », ceux qui habitent autrement, suivant leurs propres formes, manières, mœurs, rythmes, mais aussi ceux qui engendrent et entretiennent, à toutes les échelles, ce que nous appelons notre « monde ». Si nous ne regardons pas en face comment ces autres peuples sont eux aussi affectés dans leurs corps, frappés dans leur existence, poussés à l’indiscipline ou à l’extinction par l’agressivité des usages capitalistes, comment pouvons-nous prétendre mieux habiter la Terre ou défendre un monde plus juste ?<br/>L’attention au sort de ces peuples-là n’est pas une diversion par rapport au « vrai combat » social, au travail politique : leur situation critique révèle le type d’antagonisme politique qu’il faut construire maintenant contre les forces qui détruisent notre commune planète. Au cœur des luttes contemporaines et à venir, ce qui est mis en jeu n’est pas seulement notre commune humanité contre l’injustice sociale – notre capacité à mieux redistribuer les richesses, à diminuer le temps de travail hétéronome, à organiser un mouvement populaire de reprise de contrôle sur les émissions de CO2</span></div></div>
# ```
#
# ### Chapitre lié à la note :
# ```html
# <div style="font-size: 14pt; text-align: left; margin-top: 0.5em; margin-bottom: 0.3em;"><span style="font-weight: bold; color: #48b4c1;">Introduction</span></div>
# ```
#
# ### Date et heure de la note
# ```html
# <div style="padding-top: 1em; padding-bottom: 1em; border-top: 1px dotted lightgray;"><div style="font-size: 10pt; margin-bottom: 1em; padding-left: 8px; border-left: 5px solid #ed6c00; color: #888888;">2025-07-06 23:45:32</div>
# ```
#
# ### Texte
# ```html
# <div style="font-size: 12pt;"><span>Nous sommes entouré·es, traversé·es par d’autres « peuples », ceux qui habitent autrement, suivant leurs propres formes, manières, mœurs, rythmes, mais aussi ceux qui engendrent et entretiennent, à toutes les échelles, ce que nous appelons notre « monde ». Si nous ne regardons pas en face comment ces autres peuples sont eux aussi affectés dans leurs corps, frappés dans leur existence, poussés à l’indiscipline ou à l’extinction par l’agressivité des usages capitalistes, comment pouvons-nous prétendre mieux habiter la Terre ou défendre un monde plus juste ?<br/>L’attention au sort de ces peuples-là n’est pas une diversion par rapport au « vrai combat » social, au travail politique : leur situation critique révèle le type d’antagonisme politique qu’il faut construire maintenant contre les forces qui détruisent notre commune planète. Au cœur des luttes contemporaines et à venir, ce qui est mis en jeu n’est pas seulement notre commune humanité contre l’injustice sociale – notre capacité à mieux redistribuer les richesses, à diminuer le temps de travail hétéronome, à organiser un mouvement populaire de reprise de contrôle sur les émissions de CO2</span></div></div>
# ```

# %% [markdown]
# ___
# ## Import du fichier, puis extraction du titre et des divisions du corps

# %%
def html_extraction():
    html_path = filedialog.askopenfilename(filetypes=[("HTML files", "*.html")])
    if not html_path:
        return None, None  # ou lève une exception, ou gère le cas d'annulation

    with open(html_path, "r", encoding="utf-8") as f:
        html_content = f.read()

    soup = BeautifulSoup(html_content, "lxml")

    # title extraction
    title = soup.title.string if soup.title else ""

    # body division
    body = soup.body
    divs = body.find_all("div", recursive=False)  # exemple

    return divs, title

# %% [markdown]
# ## Création de la bibliothèque de citations.
# Chaque citation contient :
# - chapter
# - date
# - text
#
# Si le html contient du 14pt (les titres) alors on note un chapitre
# Sinon on subdivise en date et texte
#
# ATTENTION Il peut y avoir plusieurs dates/textes pour un seul chapitre

# %%
def citation_library_creation(divs):
    citations = []
    i = 0
    while i<len(divs)-1:
        if "font-size: 14pt" in divs[i].get("style", ""):
            current_chapter = divs[i].get_text(strip=True)
        else:
            subdiv = divs[i].find_all("div", recursive=False)
            date = subdiv[0].get_text(strip=True)
            text = "> " + subdiv[1].get_text(separator="\n >\n > ", strip=True)
            citations.append({
                "chapter": current_chapter,
                "date": date,
                "text": text
            })
        i+=1
    return citations

# %% [markdown]
# Interface de remplissage des métadonnées. La bibliothèque contient :
#     "tags": [...],      # Liste de tags (séparés par des virgules, espaces supprimés)
#     "authors": [...],   # Liste d'auteurs (idem)
#     "pubdate": "...",   # Date de parution (YYYY-MM-DD)
#     "reading": "...",   # Date de lecture (YYYY-MM-DD)
#     "isbn": "...",      # ISBN
#     "type": "..."       # Type (par défaut "fiche de lecture")

# %%
class MetadataDialog(simpledialog.Dialog):
    def body(self, master):
        self.result = {}
        tk.Label(master, text="tags (séparés par des virgules) :").grid(row=0, sticky="w")
        self.tags = tk.Entry(master, width=40)
        self.tags.grid(row=0, column=1)
        tk.Label(master, text="Auteurices (séparés par des virgules) :").grid(row=1, sticky="w")
        self.authors = tk.Entry(master, width=40)
        self.authors.grid(row=1, column=1)
        tk.Label(master, text="Parution (YYYY-MM-DD) :").grid(row=2, sticky="w")
        self.pubdate = tk.Entry(master, width=40)
        self.pubdate.grid(row=2, column=1)
        tk.Label(master, text="Lecture (YYYY-MM-DD) :").grid(row=3, sticky="w")
        self.reading = tk.Entry(master, width=40)
        self.reading.grid(row=3, column=1)
        tk.Label(master, text="ISBN :").grid(row=4, sticky="w")
        self.isbn = tk.Entry(master, width=40)
        self.isbn.grid(row=4, column=1)
        tk.Label(master, text="type :").grid(row=5, sticky="w")
        self.type = tk.Entry(master, width=40)
        self.type.insert(0, "fiche de lecture")
        self.type.grid(row=5, column=1)
        return self.tags

    def apply(self):
        self.result = {
            "tags": [t.strip() for t in self.tags.get().split(",") if t.strip()],
            "authors": [a.strip() for a in self.authors.get().split(",") if a.strip()],
            "pubdate": self.pubdate.get().strip(),
            "reading": self.reading.get().strip(),
            "isbn": self.isbn.get().strip(),
            "type": self.type.get().strip(),
        }

# %% [markdown]
# ## Revue des citations :
#     "type": "...",        # Le type choisi dans la liste déroulante (ex: "exemple", "important", ...)
#     "tags": [...],        # Liste des tags saisis, séparés par des espaces
#     "text": "...",        # Le texte éventuellement modifié de la note
#     "chapter": "..."      # Le nom du chapitre associé à la note
# Interface graphique -> attention à bien aller du début à la fin avant de cliquer sur "terminer" !!!

# %%
class CitationReviewDialog(simpledialog.Dialog):
    def __init__(self, parent, notes):
        self.notes = notes
        self.current = 0
        self.types = ["exemple", "important", "definition", "reference", "a-revoir"]
        self.results = []
        super().__init__(parent, title="Revue des citations")

    def body(self, master):
        self.type_var = tk.StringVar(value=self.types[0])
        self.tags_var = tk.StringVar()
        self.text = scrolledtext.ScrolledText(master, width=80, height=10)
        self.text.grid(row=0, column=0, columnspan=3, pady=5)
        tk.Label(master, text="Type de note :").grid(row=1, column=0, sticky="e")
        self.type_menu = ttk.Combobox(master, textvariable=self.type_var, values=self.types, state="readonly")
        self.type_menu.grid(row=1, column=1, sticky="w")
        tk.Label(master, text="Tags (séparés par des espaces) :").grid(row=2, column=0, sticky="e")
        self.tags_entry = tk.Entry(master, textvariable=self.tags_var, width=50)
        self.tags_entry.grid(row=2, column=1, sticky="w")
        self.chap_label = tk.Label(master, text="")
        self.chap_label.grid(row=3, column=0, columnspan=3, sticky="w")
        self.update_display()
        return self.text

    def update_display(self):
        note = self.notes[self.current]
        self.text.delete("1.0", "end")
        self.text.insert("1.0", note["text"])
        self.chap_label.config(text=f"Chapitre : {note['chapter']}")
        # Affiche les valeurs déjà saisies si elles existent
        if len(self.results) > self.current and self.results[self.current]:
            self.type_var.set(self.results[self.current].get("type", self.types[0]))
            self.tags_var.set(" ".join(self.results[self.current].get("tags", [])))
        else:
            self.type_var.set(self.types[0])   # Réinitialise le type
            self.tags_var.set("")              # Réinitialise les tags


    def buttonbox(self):
        box = tk.Frame(self)
        tk.Button(box, text="Précédent", width=10, command=self.prev_note).pack(side="left")
        tk.Button(box, text="Suivant", width=10, command=self.next_note).pack(side="left")
        tk.Button(box, text="Terminer", width=10, command=self.ok).pack(side="right")
        box.pack()

    def prev_note(self):
        self.save_current()
        if self.current > 0:
            self.current -= 1
            self.update_display()

    def next_note(self):
        self.save_current()
        if self.current < len(self.notes) - 1:
            self.current += 1
            self.update_display()

    def save_current(self):
        self.tags_var.set(self.tags_entry.get())
        self.type_var.set(self.type_menu.get())

        if len(self.results) <= self.current:
            self.results += [{}] * (self.current - len(self.results) + 1)
        self.results[self.current] = {
            "type": self.type_var.get(),
            "tags": [t for t in self.tags_var.get().split() if t],
            "text": self.text.get("1.0", "end-1c"),
            "chapter": self.notes[self.current]["chapter"]
        }
        print("Sauvegarde:", self.results[self.current])


    def apply(self):
        self.save_current()
        self.result = self.results

# %% [markdown]
# ## Génération du markdown
# - d'abord les métadonnées
# - ensuite l'encadré contenant le lien (à revoir, le lien se fait mal pour le moment)
# - enfin écriture des citations avec les types, noms de chapitres, textes et tags choisis

# %%
def notes_to_markdown(title, meta, citations):
    # Métadonnées
    md = "---\n"
    md += "tags:\n"
    for t in meta["tags"]:
        md += f"  - {t}\n"
    md += "Auteurices:\n"
    for a in meta["authors"]:
        md += f"  - {a}\n"
    if meta["pubdate"]: md += f"Parution: {meta['pubdate']}\n"
    if meta["reading"]: md += f"Lecture: {meta['reading']}\n"
    # Insertion du titre défini au départ
    md += "Référence(s):\n"
    md += f"  - {title}\n"
    if meta["isbn"]: md += f"ISBN: {meta['isbn']}\n"
    if meta["type"]: md += f"type: {meta['type']}\n"
    md += "---\n\n"
    # Encadré livre
    md += "> [!book]\n"
    md += f"> ![[{title}.epub]]\n\n"
    # Citations
    for c in citations:
        # ajout des # dans les tags
        tag_str = " ".join(f"#{t}" for t in c["tags"])
        md += f'> [!{c["type"]}]+ {c["chapter"]}\n {c["text"]}\n> {tag_str}\n\n'
    return md

# %% [markdown]
# ## Main

# %%
from bs4 import BeautifulSoup
import lxml
import tkinter as tk
from tkinter import simpledialog, filedialog, messagebox, ttk, scrolledtext

def main(): 
    root = tk.Tk()
    root.withdraw()

    divs, title = html_extraction()
    citations = citation_library_creation(divs)

    metadata = MetadataDialog(root, title="Entrer les métadonnées").result
    
    citations = CitationReviewDialog(root, citations).result

    md = notes_to_markdown(title, metadata, citations)

    save_path = filedialog.asksaveasfilename(defaultextension=".md", filetypes=[("Markdown", "*.md")])
    if save_path: 
        with open(save_path, "w", encoding="utf-8") as f:
            f.write(md)


if __name__ == "__main__":
    main()

# %% [markdown]
# ___
# ___
# # Code complet

# %%
from bs4 import BeautifulSoup
import lxml
import tkinter as tk
from tkinter import simpledialog, filedialog, messagebox, ttk, scrolledtext

def html_extraction():
    html_path = filedialog.askopenfilename(filetypes=[("HTML files", "*.html")])
    if not html_path:
        return None, None  # ou lève une exception, ou gère le cas d'annulation

    with open(html_path, "r", encoding="utf-8") as f:
        html_content = f.read()

    soup = BeautifulSoup(html_content, "lxml")

    # title extraction
    title = soup.title.string if soup.title else ""

    # body division
    body = soup.body
    divs = body.find_all("div", recursive=False)  # exemple

    return divs, title

class MetadataDialog(simpledialog.Dialog):
    def body(self, master):
        self.result = {}
        tk.Label(master, text="tags (séparés par des virgules) :").grid(row=0, sticky="w")
        self.tags = tk.Entry(master, width=40)
        self.tags.grid(row=0, column=1)
        tk.Label(master, text="Auteurices (séparés par des virgules) :").grid(row=1, sticky="w")
        self.authors = tk.Entry(master, width=40)
        self.authors.grid(row=1, column=1)
        tk.Label(master, text="Parution (YYYY-MM-DD) :").grid(row=2, sticky="w")
        self.pubdate = tk.Entry(master, width=40)
        self.pubdate.grid(row=2, column=1)
        tk.Label(master, text="Lecture (YYYY-MM-DD) :").grid(row=3, sticky="w")
        self.reading = tk.Entry(master, width=40)
        self.reading.grid(row=3, column=1)
        tk.Label(master, text="ISBN :").grid(row=4, sticky="w")
        self.isbn = tk.Entry(master, width=40)
        self.isbn.grid(row=4, column=1)
        tk.Label(master, text="type :").grid(row=5, sticky="w")
        self.type = tk.Entry(master, width=40)
        self.type.insert(0, "fiche de lecture")
        self.type.grid(row=5, column=1)
        return self.tags

    def apply(self):
        self.result = {
            "tags": [t.strip() for t in self.tags.get().split(",") if t.strip()],
            "authors": [a.strip() for a in self.authors.get().split(",") if a.strip()],
            "pubdate": self.pubdate.get().strip(),
            "reading": self.reading.get().strip(),
            "isbn": self.isbn.get().strip(),
            "type": self.type.get().strip(),
        }

class CitationReviewDialog(simpledialog.Dialog):
    def __init__(self, parent, notes):
        self.notes = notes
        self.current = 0
        self.types = ["exemple", "important", "definition", "reference", "a-revoir"]
        self.results = []
        super().__init__(parent, title="Revue des citations")

    def body(self, master):
        self.type_var = tk.StringVar(value=self.types[0])
        self.tags_var = tk.StringVar()
        self.text = scrolledtext.ScrolledText(master, width=80, height=10)
        self.text.grid(row=0, column=0, columnspan=3, pady=5)
        tk.Label(master, text="Type de note :").grid(row=1, column=0, sticky="e")
        self.type_menu = ttk.Combobox(master, textvariable=self.type_var, values=self.types, state="readonly")
        self.type_menu.grid(row=1, column=1, sticky="w")
        tk.Label(master, text="Tags (séparés par des espaces) :").grid(row=2, column=0, sticky="e")
        self.tags_entry = tk.Entry(master, textvariable=self.tags_var, width=50)
        self.tags_entry.grid(row=2, column=1, sticky="w")
        self.chap_label = tk.Label(master, text="")
        self.chap_label.grid(row=3, column=0, columnspan=3, sticky="w")
        self.update_display()
        return self.text

    def update_display(self):
        note = self.notes[self.current]
        self.text.delete("1.0", "end")
        self.text.insert("1.0", note["text"])
        self.chap_label.config(text=f"Chapitre : {note['chapter']}")
        # Affiche les valeurs déjà saisies si elles existent
        if len(self.results) > self.current and self.results[self.current]:
            self.type_var.set(self.results[self.current].get("type", self.types[0]))
            self.tags_var.set(" ".join(self.results[self.current].get("tags", [])))
        else:
            self.type_var.set(self.types[0])   # Réinitialise le type
            self.tags_var.set("")              # Réinitialise les tags


    def buttonbox(self):
        box = tk.Frame(self)
        tk.Button(box, text="Précédent", width=10, command=self.prev_note).pack(side="left")
        tk.Button(box, text="Suivant", width=10, command=self.next_note).pack(side="left")
        tk.Button(box, text="Terminer", width=10, command=self.ok).pack(side="right")
        box.pack()

    def prev_note(self):
        self.save_current()
        if self.current > 0:
            self.current -= 1
            self.update_display()

    def next_note(self):
        self.save_current()
        if self.current < len(self.notes) - 1:
            self.current += 1
            self.update_display()

    def save_current(self):
        self.tags_var.set(self.tags_entry.get())
        self.type_var.set(self.type_menu.get())

        if len(self.results) <= self.current:
            self.results += [{}] * (self.current - len(self.results) + 1)
        self.results[self.current] = {
            "type": self.type_var.get(),
            "tags": [t for t in self.tags_var.get().split() if t],
            "text": self.text.get("1.0", "end-1c"),
            "chapter": self.notes[self.current]["chapter"]
        }
        print("Sauvegarde:", self.results[self.current])

    def apply(self):
        self.save_current()
        self.result = self.results

def notes_to_markdown(title, meta, citations):
    # Métadonnées
    md = "---\n"
    md += "tags:\n"
    for t in meta["tags"]:
        md += f"  - {t}\n"
    md += "Auteurices:\n"
    for a in meta["authors"]:
        md += f"  - {a}\n"
    if meta["pubdate"]: md += f"Parution: {meta['pubdate']}\n"
    if meta["reading"]: md += f"Lecture: {meta['reading']}\n"
    # Insertion du titre défini au départ
    md += "Référence(s):\n"
    md += f"  - {title}\n"
    if meta["isbn"]: md += f"ISBN: {meta['isbn']}\n"
    if meta["type"]: md += f"type: {meta['type']}\n"
    md += "---\n\n"
    # Encadré livre
    md += "> [!book]\n"
    md += f"> ![[{title}.epub]]\n\n"
    # Citations
    for c in citations:
        # ajout des # dans les tags
        tag_str = " ".join(f"#{t}" for t in c["tags"])
        md += f'> [!{c["type"]}]+ {c["chapter"]}\n {c["text"]}\n> {tag_str}\n\n'
    return md

def main(): 
    root = tk.Tk()
    root.withdraw()

    divs, title = html_extraction()
    citations = citation_library_creation(divs)

    metadata = MetadataDialog(root, title="Entrer les métadonnées").result
    
    citations = CitationReviewDialog(root, citations).result

    md = notes_to_markdown(title, metadata, citations)

    save_path = filedialog.asksaveasfilename(defaultextension=".md", filetypes=[("Markdown", "*.md")])
    if save_path: 
        with open(save_path, "w", encoding="utf-8") as f:
            f.write(md)


if __name__ == "__main__":
    main()
